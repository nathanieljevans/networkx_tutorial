# %%
import networkx as nx 
import pandas as pd 
from matplotlib import pyplot as plt 

from jaal import Jaal 
from jaal.datasets import load_got

import numpy as np 
from networkx.algorithms import community

import pandas as pd
from cdlib import algorithms, viz
import igraph as ig

# %% [markdown]
# # BMI 567/667 Networkx Tutorial
# ---
#
# Written by Nate Evans (evansna@ohsu.edu)
#
# ---
#
# [Networkx](https://networkx.org/documentation/stable/) is a python package developed for working with graph data. This class does not require students to use networkx or python for their projects; however, python and networkx are very powerful and extensible tools.
#
# The official `Networkx documentation` has a nice [tutorial](https://networkx.org/documentation/stable/tutorial.html), which covers much of the same material you'll see in this document. The purpose of *this* tutorial is to provide you the pythonic tools to handle BMI 567/667, and to be a "Movie Trailer" for the course - e.g., to show off some of the exciting applications of network science.
#
# Be sure to check back in on [these](https://networkx.org/documentation/stable/auto_examples/index.html) networkx examples later on.
#
# # To start, let's make a graph
#
# ---
# ---
#
# In `networkx` graph Objects are created by calling `nx.Graph()`, which will initialize and empty graph - you will need to add all the desired edges, nodes and attributes. That said, there are a number of ways to create graphs from `csv` edge lists, adjacency matrices or load common graphs into local memory.

# %%
G = nx.Graph()          # initializes an empty undirected graph object (for directed graphs, use `nx.DiGraph`) 
G.add_edge(0, 1)        # add an edge from node 0 to node 1

nx.draw_networkx(G)     # plot the graph (this uses a force directed layout, we'll talk about this below)

# %% [markdown]
# Note that previously to `G.add_edge` there were no nodes and after this there were 2. The `add_edge` function will create new nodes if they don't already exist, but will use the current node if it's already in the graph.
#
# # Nodes do not have to be integers - can be strings!
#
# Although, note that some applications of graphs require integer identifiers for each node - but we can always assign an integer mapping later.

# %%
G.add_edge('dog', 'cat')
nx.draw_networkx(G)

# %% [markdown]
# # What if I have a whole bunch of edges? Do I have to wrap this in a loop?
#
# Ick, no.

# %%
lots_of_edges = [(0, 2), (2,1), (1,'dog')]  # list of tuples containing edges connecting nodes u to v: [(u1,v1), (u2,v2),...]

G.add_edges_from(lots_of_edges)

nx.draw_networkx(G)

# %% [markdown]
# # We can add `attributes` to both **edges** and **nodes**.
#
# We can add attributes to nodes either during node creation or after the fact by accessing the node attributes directly.

# %%
# first lets create a new node with an attribute
G.add_nodes_from([
    ('tree', {"is_animal": False}),
])

# note our `tree` node doesn't have any edges yet. 
nx.draw_networkx(G)

# but we can access the node attributes by 
print('attribute dictionary:', nx.get_node_attributes(G, name='is_animal'))
# Out:
# attribute dictionary: {'tree': False}

# %%
# we can also modify attributes after node creation by directly accessing the attribute dictionary
G.nodes['cat']['is_animal'] = True
G.nodes['dog']['is_animal'] = True

for i in range(3): 
    G.nodes[i]['is_animal'] = False

nx.get_node_attributes(G, name='is_animal')
# Out:
# {0: False, 1: False, 'dog': True, 'cat': True, 2: False, 'tree': False}

# %% [markdown]
# # Let's visualize the attributes!
#
# Can't stress how valuable graph visualizations are - both to understand your data and to debug issues.

# %%
# we can also use the attributes for visualization 
attr_dict = nx.get_node_attributes(G, name='is_animal') 

nodelist = list(attr_dict.keys())
colors = [['r', 'b'][int(attr)] for attr in attr_dict.values()]

nx.draw_networkx(G, nodelist=nodelist, node_color=colors, font_color='w', node_size=700)

# %% [markdown]
# # How to add edge attributes
#
# Edges can hold attributes as well, and a common form is `edge weights` (e.g., a numerical value assigned to each edge which could represent strength, flow, or something else).

# %%
# YOUR TURN
# try adding a "good" attribute to the dog node, then plot the graph using node shape for the "good" attribute

# %% [markdown]
# # Other graph formats
#
# 1. Edge lists
# 2. Adjacency Matrices
# 3. Sparse Matrices

# %% [markdown]
# # Let's learn to navigate the graph
#
# ---
# ---
#
# **General Python Tip**: If you are every curious about the python datatype you can use the function `type()` - or if you want to know what methods are attributed to an object, use `dir()`
#
#
# `G.nodes()` returns a **nodeview** objects, which is an interable.
#
# Additionally, we can access node attributes using either the graph `G` or the `nodeview`.

# %%
for node in G.nodes(): 
    print(node)
# Out:
# 0
# 1
# dog
# cat
# 2
# tree

# %%
nodeview = G.nodes()
for node in G.nodes(): 
    print('node:', node)
    print('nodeview access:', nodeview[node])
    print('graph access:', G[node])
    print()
# Out:
# node: 0
# nodeview access: {'is_animal': False}
# graph access: {1: {}, 2: {}}
#
# node: 1
# nodeview access: {'is_animal': False}
# graph access: {0: {}, 2: {}, 'dog': {}}
#
# node: dog
# nodeview access: {'is_animal': True}
# graph access: {'cat': {}, 1: {}}
#
# node: cat
# nodeview access: {'is_animal': True}
# graph access: {'dog': {}}
#
# node: 2
# nodeview access: {'is_animal': False}
# graph access: {0: {}, 1: {}}
#
# node: tree
# nodeview access: {'is_animal': False}
# graph access: {}

# %%
G.edges()
# Out:
# EdgeView([(0, 1), (0, 2), (0, 3), (1, 2), (3, 4), (3, 5), (4, 5)])

# %%
nx.draw_networkx(G)

# %% [markdown]
# # **Question:** What does nodeview access give you? What does Graph node access return to you?
#
# ---
# Response:
#
#
#
# ---
#
#
# # What if we want to navigate along graph elements starting from a given node?
#
# For instance, what if we want to know all the neighbors of the `dog` node?
#
# ---
# Response:
#
#
# ---
#
# # Try getting all the neighbors of node 33 in the `karate club graph` ... compare to the visualization - did it work?

# %%
KCG = nx.karate_club_graph() # This is one of the datasets that networkx has stored
                             # more datasets can be found here: 

nx.draw_networkx(KCG)

# %%
# don't scroll down until you have tried this yourself :)

# %%
neighbors33 = [x for x in KCG.neighbors(33)] + [33]
print('neighbors of node 33:', neighbors33)
# Out:
# neighbors of node 33: [8, 9, 13, 14, 15, 18, 19, 20, 22, 23, 26, 27, 28, 29, 30, 31, 32, 33]

# %%
nx.draw_networkx(KCG, node_color=[['r', 'c'][x in neighbors33] for x in KCG.nodes()], node_size=[[200, 500][x == 33] for x in KCG.nodes()])

# %% [markdown]
# # Some other tips and tricks
#
# Altherative ways to access neighbors include `nx.neighbors(graph, node)` ... this will return a iterator of the neighbors - just like iterating through a graph node view - see the nx master plan yet?
#
# Also, I know we haven't talked about it yet, but we can also create `Directed Graphs` (DiGraphs). For these graph types, you may want to know the  `children/successors` or `parents/predecessors` for this you can use the methods: `nx.successors(graph, node)` or `nx.predecessors`.

# %% [markdown]
# # Community Detection
#
# ---
# ---
#
# Within a graph, we often want to know if there are subsets of nodes that are more strongly connected - we call such subsets a `community` and many algorithms have been developed to detect these communities.
#
# We will explore communnity detection in depth later in this course but for now, accept that one method of community detection is based on maximizing the [modularity](https://en.wikipedia.org/wiki/Modularity_(networks)) of node subsets.
#
# > `Modularity`: Modularity is the fraction of the edges that fall within the given groups minus the expected fraction if edges were distributed at random.
#
# ## Quick example

# %%
G = nx.Graph()
G.add_edges_from([(0,1), (1,2), (2,0), (3,0), (3,4), (3,5), (4,5)])
nx.draw_networkx(G)

# %% [markdown]
# ## If we had to partition this graph into two communities, what would give the highest modularity?

# %%
nx.algorithms.community.quality.modularity(G, communities=[{0,1,2},{3,4,5}])
# Out:
# 0.35714285714285715

# %%
nx.algorithms.community.quality.modularity(G, communities=[{2,3,4},{5,0,1}])
# Out:
# -0.21428571428571425

# %% [markdown]
# # Community Clustering with the `louvain` algorithm
#
# ---
# ---
#
# This method is well suited to large graphs and performs well in practice - It attempts to maximize the modularity of the partitions.
#
# For more information, see [wikipedia](https://en.wikipedia.org/wiki/Louvain_method) or [chapter 9](http://networksciencebook.com/chapter/9#modularity) of the Barbasi textbook.

# %%
coms = algorithms.louvain(KCG)

# %%
pos = nx.spring_layout(KCG) 

plt.figure()

for com,color in zip(coms.communities, ['r','b','g','c']): 
    nx.draw_networkx_nodes(KCG.subgraph(com), pos=pos, node_color=color)

nx.draw_networkx_labels(KCG, pos=pos, font_color='w')
nx.draw_networkx_edges(KCG, pos=pos)
plt.show()

# %% [markdown]
# # Graph metrics!
#
# We haven't covered this yet, but many metrics can be calculated for nodes, edges and whole-graphs. These metrics can be used to understand node or edge importance, graph connectness and density, and much more!
#
# To begin, let's introduce `node degree`: The degree of a node is the number of incoming or outgoing edges and can be further divided into `in-degree` and `out-degree`.
#
# The distribution of a graphs node-degrees is important in several ways - and this will be discussed later in the course. For now, let's explore how to get the degree of a node and graph.
#
# ![image](https://www.frontiersin.org/files/Articles/439505/fnins-13-00585-HTML-r1/image_m/fnins-13-00585-g005.jpg)
#
# Image citation:
#
# 1. Farahani FV, Karwowski W, Lighthall NR. Application of Graph Theory for Identifying Connectivity Patterns in Human Brain Networks: A Systematic Review. Front Neurosci. 2019 Jun 6;13:585. doi: 10.3389/fnins.2019.00585. PMID: 31249501; PMCID: PMC6582769.

# %%
# shockingly simple... 
G.degree()
# Out:
# DegreeView({0: 3, 1: 2, 2: 2, 3: 3, 4: 2, 5: 2})

# %%
nx.draw_networkx(G, node_color=list(dict(G.degree()).values()), font_color='r')

# %%
# for convenience, we can cast this to a dictionary ... and access attributes by key/value 
dict(G.degree()).values()
# Out:
# dict_values([2, 3, 2, 1, 2, 0])

# %%
# plot the degree distribution for 

big_G = nx.dual_barabasi_albert_graph(n=1000, m1=50, m2=50, p=0.05, seed=0)

pos = nx.spring_layout(big_G)

plt.figure(figsize=(10,10))
nx.draw_networkx_edges(big_G, pos=pos, alpha=0.01)
plt.show()

# %%
f,axes = plt.subplots(1,2, figsize=(10,5))

plt.figure()
plt.hist(dict(big_G.degree()).values(), bins=50)
plt.xlabel('degree')
plt.ylabel('count')
plt.show()

# %%
# for degree distributions, we often visualize in log counts. 

plt.figure()
plt.hist(dict(big_G.degree()).values(), bins=50)
plt.xlabel('degree')
plt.ylabel('count')
plt.yscale('log')
plt.show()

# %% [markdown]
# # BORING! Give me a more fun metric!
#
# Okay, let's calculate `degree centrality` - this is a general metric of how connected a node is to the rest of the graph.

# %%
nx.centrality.degree_centrality(G)
# Out:
# {0: 0.4, 1: 0.6000000000000001, 'dog': 0.4, 'cat': 0.2, 2: 0.4, 'tree': 0.0}

# %%
dc = dict(nx.centrality.degree_centrality(big_G))
nodelist = list(dc.keys())
centrality = list(dc.values())

plt.figure(figsize=(10,10))
nx.draw_networkx_edges(big_G, pos=pos, alpha=0.01)
nx.draw_networkx_nodes(big_G, pos=pos, nodelist=nodelist, node_color=centrality, alpha=1, node_size=10)
plt.show()

# %% [markdown]
# # Clustering Coeficient
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/0/0f/Clustering_coefficient_example.svg/320px-Clustering_coefficient_example.svg.png" alt="drawing" width="100"/>
#
# > [Wikipedia](https://en.wikipedia.org/wiki/Clustering_coefficient): "Example local clustering coefficient on an undirected graph. The local clustering coefficient of the blue node is computed as the proportion of connections among its neighbours which are actually realised compared with the number of all possible connections. In the figure, the blue node has three neighbours, which can have a maximum of 3 connections among them. In the top part of the figure all three possible connections are realised (thick black segments), giving a local clustering coefficient of 1. In the middle part of the figure only one connection is realised (thick black line) and 2 connections are missing (dotted red lines), giving a local cluster coefficient of 1/3. Finally, none of the possible connections among the neighbours of the blue node are realised, producing a local clustering coefficient value of 0."

# %%
cluster_coef = nx.algorithms.cluster.clustering(KCG)

plt.figure(figsize=(15,8))
nx.draw_networkx(KCG, node_color=list(dict(cluster_coef).values()))
plt.show()

# %% [markdown]
# # Little more about graph visualization in networkx
#
# `networkx`'s plotting is built on top of `matplotlib`, so everyone who is familiar with this plotting package should be able to follow the syntax. If you are not familiar, I recommend reviewing some of the following resources:
#
# - [Matplotlib documentation & tutorials](https://matplotlib.org/stable/tutorials/index)
# - [Towards tutorial](https://towardsdatascience.com/matplotlib-tutorial-learn-basics-of-pythons-powerful-plotting-library-b5d1b8f67596)
# - [Datacamp](https://www.datacamp.com/community/tutorials/matplotlib-tutorial-python) - *requires account*

# %%
pos = {0:(0,1), 1:()}

# %%
nx.spring_layout(G)
# Out:
# {0: array([0.39171728, 0.09913518]),
#  1: array([0.89070145, 0.45413864]),
#  2: array([0.99947299, 0.02414001]),
#  3: array([-0.39141293, -0.09902792]),
#  4: array([-0.89047879, -0.45556204]),
#  5: array([-1.        , -0.02282388])}

# %%
# break - make a shape

# %% [markdown]
# # Alternative Graph Visualization Tools
#
# Other tools, like `cytoscape`, `igraph`, `graphviz` or `graphia` are better suited for large graph visualization.
#
#
# Pythons `matplotlib` and `netowrkx` has a lot of convenience and extensibility for plotting; however, it is not interactive and I've never been completely content with the plotting layouts (like force-directed/spring or circular), especially for large graphs.
#
# To improve on this, there are some other tools that have been developed for interactive graph visualization. Dr. Wu will introduce you to cytoscape. One pythonic approach that I like is the `Jaal` package.
#
# Let's try out Jaal...

# %%
edge_df, node_df = load_got() 

edge_df.head()
# Out:
#                               from                  to  weight strength
# 0  Aemon-Targaryen-(Maester-Aemon)        Jeor-Mormont      13   medium
# 1  Aemon-Targaryen-(Maester-Aemon)            Jon-Snow      34   medium
# 2               Aerys-II-Targaryen    Robert-Baratheon      12   medium
# 3                             Aggo  Daenerys-Targaryen      11   medium
# 4                   Alliser-Thorne            Jon-Snow      32   medium

# %%
node_df.head()
# Out:
#                   id  gender  screentime
# 0    Illyrio-Mopatis    male        3.30
# 1        Jory-Cassel    male        6.15
# 2  Viserys-Targaryen    male       20.30
# 3     Mirri-Maz-Duur  female        7.30
# 4              Jhogo    male        1.00

# %%
# Jaal for network visualization 
Jaal(edge_df, node_df).plot()
# Out:
# Parsing the data...Done
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app '__main__' (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [03/Jan/2022 15:08:18] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Jan/2022 15:08:18] "GET /_dash-component-suites/dash/deps/polyfill@7.v2_0_0m1641170616.12.1.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Jan/2022 15:08:18] "GET /_dash-component-suites/dash/deps/prop-types@15.v2_0_0m1641170616.7.2.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Jan/2022 15:08:18] "GET /_dash-component-suites/dash/deps/react@16.v2_0_0m1641170616.14.0.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Jan/2022 15:08:18] "GET /_dash-component-suites/dash/deps/react-dom@16.v2_0_0m1641170616.14.0.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Jan/2022 15:08:18] "GET /_dash-component-suites/dash_bootstrap_components/_components/dash_bootstrap_components.v0_13_1m1641170617.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Jan/2022 15:08:18] "GET /_dash-component-suites/visdcc/bundle.v0_0_40m1641170616.js HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Jan/2022 15:08:18] "GET /_dash-component-suites/dash/dash-renderer/build/dash_renderer.v2_0_0m1641170616.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Jan/2022 15:08:18] "GET /_dash-component-suites/dash/dcc/dash_core_components.v2_0_0m1641170616.js HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Jan/2022 15:08:18] "GET /_dash-component-suites/dash/dcc/dash_core_components-shared.v2_0_0m1641170616.js HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Jan/2022 15:08:18] "GET /_dash-component-suites/dash/html/dash_html_components.v2_0_0m1641170616.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Jan/2022 15:08:18] "GET /_dash-component-suites/dash/dash_table/bundle.v5_0_0m1641170616.js HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Jan/2022 15:08:19] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Jan/2022 15:08:19] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Jan/2022 15:08:19] "GET /_favicon.ico?v=2.0.0 HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Jan/2022 15:08:19] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Jan/2022 15:08:19] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Jan/2022 15:08:19] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Jan/2022 15:08:19] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Jan/2022 15:08:19] "POST /_dash-update-component HTTP/1.1" 200 -
# No trigger
# 127.0.0.1 - - [03/Jan/2022 15:08:26] "POST /_dash-update-component HTTP/1.1" 200 -
# inside color node gender
# 127.0.0.1 - - [03/Jan/2022 15:08:27] "POST /_dash-update-component HTTP/1.1" 200 -
# inside color edge strength
# 127.0.0.1 - - [03/Jan/2022 15:08:28] "POST /_dash-update-component HTTP/1.1" 200 -
# Modifying node size using  screentime
# 127.0.0.1 - - [03/Jan/2022 15:08:29] "POST /_dash-update-component HTTP/1.1" 200 -
# Modifying edge size using  weight
# 127.0.0.1 - - [03/Jan/2022 15:08:44] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Jan/2022 15:08:44] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Jan/2022 15:08:44] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Jan/2022 15:08:44] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Jan/2022 15:08:45] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Jan/2022 15:08:46] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Jan/2022 15:08:46] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Jan/2022 15:08:46] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Jan/2022 15:08:47] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Jan/2022 15:08:47] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Jan/2022 15:08:48] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Jan/2022 15:08:53] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Jan/2022 15:08:53] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Jan/2022 15:08:53] "POST /_dash-update-component HTTP/1.1" 200 -

# %% [markdown]
# # Let's do a real analysis!
#
# Download [this](https://reactome.org/download/tools/ReatomeFIs/FIsInGene_122220_with_annotations.txt) file. It contains the Reactome Functional Interaction (FI) network. This is already done! Data is located in `data/`.
#
# citation:
#
# Wu, G., Feng, X. & Stein, L. A human functional protein interaction network and its application to cancer data analysis. Genome Biol 11, R53 (2010). https://doi.org/10.1186/gb-2010-11-5-r53

# %%
fi_data = pd.read_csv('data/FIsInGene_122220_with_annotations.txt', sep='\t')
fi_data.head()
# Out:
#     Gene1    Gene2                    Annotation Direction  Score
# 0  16-5-5    CDC42                     predicted         -   0.98
# 1  16-5-5    PARD3                     predicted         -   1.00
# 2  16-5-5   PARD3B                     predicted         -   1.00
# 3    A1CF  APOBEC1  catalyzed by; complex; input        <-   1.00
# 4    A1CF    EP300       expression regulated by        <-   1.00

# %%
# what type of edges are there? 
fi_data.groupby('Annotation').count()['Gene1'].sort_values(ascending=False).head(10)
# Out:
# Annotation
# complex; input                            64423
# predicted                                 41182
# complex                                   16502
# catalyzed by                              11337
# catalyze                                  10691
# input                                      8231
# catalyze; catalyzed by; complex; input     7698
# activated by                               6674
# activate                                   5677
# catalyze; catalyzed by; input              5501
# Name: Gene1, dtype: int64

# %%
# what directions types are there? 
fi_data.groupby('Direction').count()['Gene1']
# Out:
# Direction
# -      146616
# ->      41272
# -|       4748
# <-      43056
# <->     15413
# <-|      1043
# |-       5554
# |->      1376
# |-|        73
# Name: Gene1, dtype: int64

# %%
fi_G = nx.from_pandas_edgelist(fi_data, source='Gene1', target='Gene2', edge_attr=['Annotation', 'Direction', 'Score'])

# %%
# first, let's get some basic info... (extract this info directly from the graph object, e.g., don't use the dataframe) 

n_nodes = len(fi_G)
print(f'how many nodes/genes are there? {n_nodes}')

n_edges = len(fi_G.edges())
print(f'how many edges are there? {n_edges}')

n_pred_edges = len([x for x in nx.get_edge_attributes(fi_G, 'Annotation').values() if x == 'predicted'])
print(f'how many `predicted` edges are there? {n_pred_edges}')

n_known_edges = len([x for x in nx.get_edge_attributes(fi_G, 'Annotation').values() if x != 'predicted'])
print(f'how many true/known edges are there? {n_known_edges}')

print(f'percentage of predicted edges: {(100*n_pred_edges / (n_known_edges + n_pred_edges)):.2f} %')


## plot the distribution of edge "score" of "predicted" edges. 
#### what y-axis scaling is most useful? 
scores = nx.get_edge_attributes(fi_G, 'Score')
annot = nx.get_edge_attributes(fi_G, 'Annotation')
pred_scores = [scores[edge] for edge in annot if annot[edge] == 'predicted']

plt.figure() 
plt.hist(pred_scores, bins=25)
plt.yscale('log')
plt.show()
# Out:
# how many nodes/genes are there? 14006
# how many edges are there? 259151
# how many `predicted` edges are there? 41182
# how many true/known edges are there? 217969
# percentage of predicted edges: 15.89 %

# %% [markdown]
# # What does the degree distribution look like?

# %%
plt.figure()
plt.hist(dict(fi_G.degree()).values(), bins=50)
plt.yscale('log')
plt.show()

# %% [markdown]
# # Who are these nodes with really high degree?
#
# Represent "Hubs" in the protein-protein interaction network - what might this mean?

# %%
{k:v for k,v in dict(fi_G.degree()).items() if v > 750}
# Out:
# {'EP300': 1117,
#  'STAT1': 752,
#  'RPS27A': 969,
#  'UBA52': 942,
#  'UBB': 781,
#  'UBC': 792,
#  'PRKACA': 914,
#  'PRKACB': 753,
#  'GNB1': 989}

# %% [markdown]
# # What is the most common edge `Annotation` of the gene with highest degree?

# %%
fi_data[lambda x: ((x.Gene1 == 'EP300') | (x.Gene2 == 'EP300'))].groupby('Annotation').count()['Gene1'].sort_values(ascending=False).head(10)
# Out:
# Annotation
# expression regulates                    376
# complex; input                          154
# expression regulated by                 152
# predicted                               104
# GErel: expression                        35
# complex; input; reaction                 35
# reaction                                 35
# activate; inhibited by                   20
# GErel: expression by                     17
# complex; expression regulates; input     16
# Name: Gene1, dtype: int64

# %% [markdown]
# # Are there isolates? multiple components?
#
# A graph can be in one or many components, additionally - some nodes may not have any edges, and we call these isolates.

# %%
# how many isolates are there? 
len(list(nx.isolates(fi_G)))
# Out:
# 0

# %%
# how many components are there?
comps = list(nx.connected_components(fi_G))
len(comps)
# Out:
# 94

# %%
# are there multiple large components? 

plt.figure()
plt.hist([len(x) for x in comps], bins=np.linspace(0,10,15))
plt.show()

print('largest components:', sorted([len(x) for x in comps])[::-1][0:5])
# Out:
# largest components: [13785, 6, 5, 5, 5]

# %% [markdown]
# # Clustering Coefficient

# %%
clus_coefs = nx.cluster.clustering(fi_G)

# %%
res = pd.DataFrame({k:[v] for k,v in clus_coefs.items()}).T.reset_index().rename({0:'cluster_coef', 'index':'Gene'}, axis=1).sort_values('cluster_coef', ascending=False)
res.head()
# Out:
#          Gene  cluster_coef
# 11252  NEURL4           1.0
# 12852    MT1X           1.0
# 8678     WEE2           1.0
# 12850    MT1L           1.0
# 4305    ITM2B           1.0

# %%
plt.figure()
plt.hist(res.cluster_coef)
plt.show()

# %%
res.cluster_coef.mean()
# Out:
# 0.37429054765775677

# %% [markdown]
# # Let's focus on just the largest component - filter all other nodes

# %%
fi_G2 = nx.subgraph(fi_G, comps[0])
len(fi_G2) # confirm we used the right component
# Out:
# 13785

# %% [markdown]
# # Plot the graph

# %%
# this can take a while (~1-5 minutes) so make sure to just do it once 
# you can reduce the `iterations` (default 50) to speed the step up. 
# see docs: https://networkx.org/documentation/stable/reference/generated/networkx.drawing.layout.spring_layout.html

pos = nx.spring_layout(fi_G2, iterations=5, k=10, seed=0)
plt.figure(figsize=(10,10))
nx.draw_networkx_edges(fi_G2, pos=pos, alpha=0.002)
plt.show()

# %% [markdown]
# # Networkx and matplotlib don't handle large graph visualization well
#
# Other tools, like `cytoscape`, `igraph`, `graphviz` or `graphia` are better suited for large graph visualization.
#
# For this tutorial, let's try to focus in on a smaller piece. How do we choose though?

# %%
coms = algorithms.infomap(complexG)

for i,com in enumerate(coms.communities): 
    if len(com) > 50: print(f'community {i}: {len(com)} | density: {nx.density(fi_G2.subgraph(com)):.2f} | avg. cluster coef.: {np.array(list(nx.cluster.clustering(fi_G2.subgraph(com)).values())).mean():.3f}')
# Out:
# community 0: 2848 | density: 0.02 | avg. cluster coef.: 0.511
# community 1: 1312 | density: 0.06 | avg. cluster coef.: 0.773
# community 2: 817 | density: 0.07 | avg. cluster coef.: 0.663
# community 3: 785 | density: 0.04 | avg. cluster coef.: 0.538
# community 4: 133 | density: 0.14 | avg. cluster coef.: 0.710
# community 5: 78 | density: 0.53 | avg. cluster coef.: 0.986
# community 6: 54 | density: 0.52 | avg. cluster coef.: 0.036

# %%
fiComp = fi_G2.subgraph(coms.communities[4])

# %%
pos = nx.spring_layout(fiComp, iterations=100, seed=0)
plt.figure(figsize=(10,10))
nx.draw_networkx_edges(fiComp, pos=pos, alpha=0.1)
plt.show()

# %% [markdown]
# # Let's think about how to visualize our graph in a new way.
#
# Instead of plotting all the nodes, let's take a `graph coarsening` approach: Nodes will now represent communities (# members ~ node size) and edges represent the number of member interactions with proteins in other communities.

# %%
communities = [x for x in coms.communities if len(x) > 15]

newG = nx.Graph() 
for i,com1 in enumerate(communities): 
    newG.add_node(i, size= len(com1)) 

# add edges 
for i,com1 in enumerate(communities): 
    for j,com2 in enumerate(communities[i:]): 
        shared_edges = list(nx.algorithms.boundary.edge_boundary(fi_G2, com1, com2))
        newG.add_edge(i,j, n_edges=len(shared_edges), weight=len(shared_edges) / min([len(com1), len(com2)]))
        
newG.remove_edges_from(nx.selfloop_edges(newG))

# %%
pos = nx.spring_layout(newG)

plt.figure()
nx.draw_networkx_nodes(newG, pos=pos, nodelist=newG.nodes(), node_size=25*np.array(list(nx.get_node_attributes(newG, 'size').values()))**(0.5))
nx.draw_networkx_labels(newG, pos=pos, font_color='w')
nx.draw_networkx_edges(newG, pos=pos, edgelist=newG.edges(), width=0.2*np.array(list(nx.get_edge_attributes(newG, 'weight').values())))
plt.figure()

# %%
list(nx.get_node_attributes(newG, 'size').values())
# Out:
# [2848, 1312, 817, 785, 133, 78, 54]

# %%
coms = algorithms.infomap(complexG)
viz.plot_network_clusters(complexG, coms, pos)

# %%
h = ig.Graph.from_networkx(complexG)

# %%
f, ax1 = plt.subplots(1,1,figsize=(10,10))
layout = h.layout_kamada_kawai()
ig.plot(h, layout=layout, target=ax1)
plt.axis("off")
plt.show()

# %%
coms = algorithms.infomap(complexG)

# %%
for i,com in enumerate(coms.communities): 
    print(f'community {i}: {len(com)} | density: {nx.density(fi_G2.subgraph(com)):.2f} | avg. cluster coef.: {np.array(list(nx.cluster.clustering(fi_G2.subgraph(com)).values())).mean():.3f}')
# Out:
# community 0: 2848 | density: 0.02 | avg. cluster coef.: 0.511
# community 1: 1312 | density: 0.06 | avg. cluster coef.: 0.773
# community 2: 817 | density: 0.07 | avg. cluster coef.: 0.663
# community 3: 785 | density: 0.04 | avg. cluster coef.: 0.538
# community 4: 133 | density: 0.14 | avg. cluster coef.: 0.710
# community 5: 78 | density: 0.53 | avg. cluster coef.: 0.986
# community 6: 54 | density: 0.52 | avg. cluster coef.: 0.036
# community 7: 25 | density: 0.57 | avg. cluster coef.: 0.677
# community 8: 19 | density: 0.11 | avg. cluster coef.: 0.000
# community 9: 18 | density: 1.00 | avg. cluster coef.: 1.000
# community 10: 16 | density: 0.78 | avg. cluster coef.: 0.866
# community 11: 14 | density: 0.87 | avg. cluster coef.: 0.968
# community 12: 13 | density: 0.44 | avg. cluster coef.: 0.926
# community 13: 12 | density: 0.85 | avg. cluster coef.: 0.902
# community 14: 11 | density: 0.44 | avg. cluster coef.: 0.859
# community 15: 10 | density: 1.00 | avg. cluster coef.: 1.000
# community 16: 9 | density: 0.44 | avg. cluster coef.: 0.810
# community 17: 9 | density: 0.67 | avg. cluster coef.: 0.952
# community 18: 7 | density: 0.67 | avg. cluster coef.: 0.562
# community 19: 7 | density: 0.76 | avg. cluster coef.: 0.810
# community 20: 7 | density: 0.71 | avg. cluster coef.: 0.514
# community 21: 7 | density: 0.29 | avg. cluster coef.: 0.000
# community 22: 6 | density: 0.87 | avg. cluster coef.: 0.900
# community 23: 6 | density: 1.00 | avg. cluster coef.: 1.000
# community 24: 6 | density: 1.00 | avg. cluster coef.: 1.000
# community 25: 6 | density: 0.80 | avg. cluster coef.: 0.900
# community 26: 6 | density: 1.00 | avg. cluster coef.: 1.000
# community 27: 6 | density: 0.33 | avg. cluster coef.: 0.000
# community 28: 6 | density: 1.00 | avg. cluster coef.: 1.000
# community 29: 6 | density: 0.87 | avg. cluster coef.: 0.900
# community 30: 6 | density: 1.00 | avg. cluster coef.: 1.000
# community 31: 6 | density: 0.33 | avg. cluster coef.: 0.000
# community 32: 5 | density: 1.00 | avg. cluster coef.: 1.000
# community 33: 5 | density: 0.60 | avg. cluster coef.: 0.600
# community 34: 5 | density: 1.00 | avg. cluster coef.: 1.000
# community 35: 5 | density: 0.50 | avg. cluster coef.: 0.433
# community 36: 5 | density: 1.00 | avg. cluster coef.: 1.000
# community 37: 5 | density: 0.40 | avg. cluster coef.: 0.000
# community 38: 5 | density: 0.50 | avg. cluster coef.: 0.433
# community 39: 5 | density: 0.00 | avg. cluster coef.: nan
# community 40: 5 | density: 0.00 | avg. cluster coef.: nan
# community 41: 5 | density: 0.70 | avg. cluster coef.: 0.767
# community 42: 5 | density: 1.00 | avg. cluster coef.: 1.000
# community 43: 5 | density: 0.80 | avg. cluster coef.: 0.667
# community 44: 4 | density: 0.83 | avg. cluster coef.: 0.833
# community 45: 4 | density: 0.83 | avg. cluster coef.: 0.833
# community 46: 4 | density: 1.00 | avg. cluster coef.: 1.000
# community 47: 4 | density: 0.83 | avg. cluster coef.: 0.833
# community 48: 4 | density: 0.50 | avg. cluster coef.: 0.000
# community 49: 4 | density: 0.50 | avg. cluster coef.: 0.000
# community 50: 4 | density: 1.00 | avg. cluster coef.: 1.000
# community 51: 4 | density: 1.00 | avg. cluster coef.: 1.000
# community 52: 4 | density: 0.83 | avg. cluster coef.: 0.833
# community 53: 4 | density: 0.67 | avg. cluster coef.: 0.583
# community 54: 4 | density: 1.00 | avg. cluster coef.: 1.000
# community 55: 4 | density: 0.83 | avg. cluster coef.: 0.833
# community 56: 4 | density: 1.00 | avg. cluster coef.: 1.000
# community 57: 4 | density: 1.00 | avg. cluster coef.: 1.000
# community 58: 4 | density: 1.00 | avg. cluster coef.: 1.000
# community 59: 4 | density: 1.00 | avg. cluster coef.: 1.000
# community 60: 4 | density: 0.50 | avg. cluster coef.: 0.000
# community 61: 4 | density: 1.00 | avg. cluster coef.: 1.000
# community 62: 4 | density: 0.50 | avg. cluster coef.: 0.000
# community 63: 4 | density: 1.00 | avg. cluster coef.: 1.000
# community 64: 4 | density: 1.00 | avg. cluster coef.: 1.000
# community 65: 4 | density: 1.00 | avg. cluster coef.: 1.000
# community 66: 3 | density: 1.00 | avg. cluster coef.: 1.000
# community 67: 3 | density: 1.00 | avg. cluster coef.: 1.000
# community 68: 3 | density: 0.67 | avg. cluster coef.: 0.000
# community 69: 3 | density: 0.67 | avg. cluster coef.: 0.000
# community 70: 3 | density: 0.67 | avg. cluster coef.: 0.000
# community 71: 3 | density: 0.00 | avg. cluster coef.: nan
# community 72: 3 | density: 1.00 | avg. cluster coef.: 1.000
# community 73: 3 | density: 1.00 | avg. cluster coef.: 1.000
# community 74: 3 | density: 1.00 | avg. cluster coef.: 1.000
# community 75: 3 | density: 1.00 | avg. cluster coef.: 1.000
# community 76: 3 | density: 1.00 | avg. cluster coef.: 1.000
# community 77: 3 | density: 0.67 | avg. cluster coef.: 0.000
# community 78: 3 | density: 0.00 | avg. cluster coef.: nan
# community 79: 3 | density: 1.00 | avg. cluster coef.: 1.000
# community 80: 3 | density: 1.00 | avg. cluster coef.: 1.000
# community 81: 3 | density: 0.67 | avg. cluster coef.: 0.000
# community 82: 3 | density: 1.00 | avg. cluster coef.: 1.000
# community 83: 3 | density: 1.00 | avg. cluster coef.: 1.000
# community 84: 3 | density: 1.00 | avg. cluster coef.: 1.000
# community 85: 3 | density: 1.00 | avg. cluster coef.: 1.000
# community 86: 3 | density: 1.00 | avg. cluster coef.: 1.000
# community 87: 3 | density: 0.67 | avg. cluster coef.: 0.000
# community 88: 3 | density: 1.00 | avg. cluster coef.: 1.000
# community 89: 3 | density: 0.67 | avg. cluster coef.: 0.000
# community 90: 3 | density: 1.00 | avg. cluster coef.: 1.000
# community 91: 3 | density: 0.67 | avg. cluster coef.: 0.000
# community 92: 3 | density: 0.67 | avg. cluster coef.: 0.000
# community 93: 3 | density: 0.67 | avg. cluster coef.: 0.000
# community 94: 3 | density: 1.00 | avg. cluster coef.: 1.000
# community 95: 3 | density: 1.00 | avg. cluster coef.: 1.000
# community 96: 3 | density: 0.67 | avg. cluster coef.: 0.000
# community 97: 3 | density: 0.00 | avg. cluster coef.: nan
# community 98: 3 | density: 0.67 | avg. cluster coef.: 0.000
# community 99: 2 | density: 1.00 | avg. cluster coef.: 0.000
# community 100: 2 | density: 1.00 | avg. cluster coef.: 0.000
# community 101: 2 | density: 0.00 | avg. cluster coef.: nan
# community 102: 2 | density: 1.00 | avg. cluster coef.: 0.000
# community 103: 2 | density: 0.00 | avg. cluster coef.: nan
# community 104: 2 | density: 1.00 | avg. cluster coef.: 0.000
# community 105: 2 | density: 1.00 | avg. cluster coef.: 0.000
# community 106: 2 | density: 1.00 | avg. cluster coef.: 0.000
# community 107: 2 | density: 1.00 | avg. cluster coef.: 0.000
# community 108: 2 | density: 0.00 | avg. cluster coef.: nan
# community 109: 2 | density: 1.00 | avg. cluster coef.: 0.000
# community 110: 2 | density: 1.00 | avg. cluster coef.: 0.000
# community 111: 2 | density: 1.00 | avg. cluster coef.: 0.000
# community 112: 2 | density: 0.00 | avg. cluster coef.: nan
# community 113: 2 | density: 1.00 | avg. cluster coef.: 0.000
# community 114: 2 | density: 1.00 | avg. cluster coef.: 0.000
# community 115: 2 | density: 1.00 | avg. cluster coef.: 0.000
# community 116: 2 | density: 1.00 | avg. cluster coef.: 0.000
# community 117: 2 | density: 1.00 | avg. cluster coef.: 0.000
# community 118: 2 | density: 1.00 | avg. cluster coef.: 0.000
# community 119: 2 | density: 0.00 | avg. cluster coef.: nan
# community 120: 2 | density: 0.00 | avg. cluster coef.: nan
# community 121: 2 | density: 1.00 | avg. cluster coef.: 0.000
# community 122: 2 | density: 0.00 | avg. cluster coef.: nan
# community 123: 2 | density: 1.00 | avg. cluster coef.: 0.000
# community 124: 2 | density: 1.00 | avg. cluster coef.: 0.000
# community 125: 2 | density: 1.00 | avg. cluster coef.: 0.000
# community 126: 2 | density: 1.00 | avg. cluster coef.: 0.000
# community 127: 2 | density: 1.00 | avg. cluster coef.: 0.000
# community 128: 2 | density: 1.00 | avg. cluster coef.: 0.000
# community 129: 2 | density: 1.00 | avg. cluster coef.: 0.000
# community 130: 2 | density: 1.00 | avg. cluster coef.: 0.000
# community 131: 2 | density: 1.00 | avg. cluster coef.: 0.000
# community 132: 2 | density: 0.00 | avg. cluster coef.: nan
# community 133: 2 | density: 1.00 | avg. cluster coef.: 0.000
# community 134: 2 | density: 1.00 | avg. cluster coef.: 0.000
# community 135: 2 | density: 1.00 | avg. cluster coef.: 0.000
# community 136: 2 | density: 1.00 | avg. cluster coef.: 0.000
# community 137: 2 | density: 1.00 | avg. cluster coef.: 0.000
# community 138: 2 | density: 1.00 | avg. cluster coef.: 0.000
# community 139: 2 | density: 0.00 | avg. cluster coef.: nan
# community 140: 2 | density: 1.00 | avg. cluster coef.: 0.000
# community 141: 2 | density: 1.00 | avg. cluster coef.: 0.000
# community 142: 2 | density: 1.00 | avg. cluster coef.: 0.000
# community 143: 2 | density: 0.00 | avg. cluster coef.: nan
# community 144: 2 | density: 1.00 | avg. cluster coef.: 0.000
# community 145: 2 | density: 1.00 | avg. cluster coef.: 0.000
# community 146: 2 | density: 1.00 | avg. cluster coef.: 0.000
# community 147: 2 | density: 1.00 | avg. cluster coef.: 0.000
# community 148: 2 | density: 1.00 | avg. cluster coef.: 0.000
# community 149: 2 | density: 1.00 | avg. cluster coef.: 0.000
# community 150: 2 | density: 1.00 | avg. cluster coef.: 0.000
# community 151: 2 | density: 1.00 | avg. cluster coef.: 0.000
# community 152: 2 | density: 1.00 | avg. cluster coef.: 0.000
# community 153: 2 | density: 1.00 | avg. cluster coef.: 0.000
# community 154: 2 | density: 1.00 | avg. cluster coef.: 0.000
# community 155: 2 | density: 1.00 | avg. cluster coef.: 0.000
# community 156: 2 | density: 1.00 | avg. cluster coef.: 0.000
# community 157: 2 | density: 1.00 | avg. cluster coef.: 0.000
# community 158: 2 | density: 1.00 | avg. cluster coef.: 0.000
# community 159: 2 | density: 1.00 | avg. cluster coef.: 0.000
# community 160: 2 | density: 1.00 | avg. cluster coef.: 0.000
# community 161: 2 | density: 1.00 | avg. cluster coef.: 0.000
# community 162: 2 | density: 1.00 | avg. cluster coef.: 0.000
# community 163: 2 | density: 1.00 | avg. cluster coef.: 0.000
# community 164: 2 | density: 1.00 | avg. cluster coef.: 0.000
# community 165: 2 | density: 1.00 | avg. cluster coef.: 0.000
# community 166: 2 | density: 1.00 | avg. cluster coef.: 0.000
# community 167: 2 | density: 0.00 | avg. cluster coef.: nan
# community 168: 2 | density: 1.00 | avg. cluster coef.: 0.000
# community 169: 2 | density: 1.00 | avg. cluster coef.: 0.000
# community 170: 2 | density: 0.00 | avg. cluster coef.: nan
# community 171: 2 | density: 1.00 | avg. cluster coef.: 0.000
# community 172: 2 | density: 0.00 | avg. cluster coef.: nan
# community 173: 2 | density: 1.00 | avg. cluster coef.: 0.000
# community 174: 2 | density: 1.00 | avg. cluster coef.: 0.000
# community 175: 2 | density: 1.00 | avg. cluster coef.: 0.000
# community 176: 2 | density: 1.00 | avg. cluster coef.: 0.000
# community 177: 2 | density: 1.00 | avg. cluster coef.: 0.000
# community 178: 2 | density: 1.00 | avg. cluster coef.: 0.000
# community 179: 2 | density: 1.00 | avg. cluster coef.: 0.000
# community 180: 2 | density: 1.00 | avg. cluster coef.: 0.000
# community 181: 2 | density: 1.00 | avg. cluster coef.: 0.000
# community 182: 2 | density: 0.00 | avg. cluster coef.: nan
# community 183: 2 | density: 0.00 | avg. cluster coef.: nan
# community 184: 2 | density: 0.00 | avg. cluster coef.: nan
# community 185: 2 | density: 1.00 | avg. cluster coef.: 0.000
# community 186: 2 | density: 1.00 | avg. cluster coef.: 0.000
# community 187: 2 | density: 1.00 | avg. cluster coef.: 0.000
# community 188: 2 | density: 1.00 | avg. cluster coef.: 0.000
# community 189: 2 | density: 0.00 | avg. cluster coef.: nan
# community 190: 2 | density: 1.00 | avg. cluster coef.: 0.000
# community 191: 2 | density: 1.00 | avg. cluster coef.: 0.000
# community 192: 2 | density: 1.00 | avg. cluster coef.: 0.000
# community 193: 2 | density: 1.00 | avg. cluster coef.: 0.000
# community 194: 2 | density: 1.00 | avg. cluster coef.: 0.000

# %%
_ = [print(x) for x in coms.communities[5] if len(x.split(' ')) == 1]
# Out:
# ACAD9
# ECSIT
# MT-ND1
# MT-ND2
# MT-ND3
# MT-ND4
# MT-ND5
# MT-ND6
# NDUFA1
# NDUFA10
# NDUFA11
# NDUFA12
# NDUFA13
# NDUFA2
# NDUFA3
# NDUFA5
# NDUFA6
# NDUFA7
# NDUFA8
# NDUFA9
# NDUFAB1
# NDUFAF1
# NDUFAF2
# NDUFAF3
# NDUFAF4
# NDUFAF5
# NDUFAF6
# NDUFAF7
# NDUFB1
# NDUFB10
# NDUFB11
# NDUFB2
# NDUFB3
# NDUFB4
# NDUFB5
# NDUFB6
# NDUFB7
# NDUFB8
# NDUFB9
# NDUFC1
# NDUFC2
# NDUFS1
# NDUFS2
# NDUFS3
# NDUFS4
# NDUFS5
# NDUFS6
# NDUFS7
# NDUFS8
# NDUFV1
# NDUFV2
# NDUFV3
# TIMMDC1
# TMEM126B
# APOO
# APOOL
# CHCHD3
# CHCHD6
# DNAJC11
# HSPA9
# IMMT
# MICOS10
# MICOS13
# MTX1
# MTX2
# SAMM50
# TMEM11
# DNAJC19
# GRPEL1
# GRPEL2
# OTC
# PAM16
# TIMM17A
# TIMM17B
# TIMM21
# TIMM23
# TIMM44
# TIMM50

# %%
# we could use communities 
coms = algorithms.louvain(fi_G2)

# %%
plt.figure(figsize=(15,15))
pos = nx.spring_layout(fi_G2.subgraph(coms.communities[0]), k=1)
nx.draw_networkx_edges(fi_G2.subgraph(coms.communities[0]), pos=pos, alpha=0.002)
plt.show()

# %%
np.array(list(nx.cluster.clustering(fi_G2.subgraph(com)).values())).mean()
# Out:
# 0.3345189118498709

# %%
for i,com in enumerate(coms.communities): 
    print(f'community {i}: {len(com)} | density: {nx.density(fi_G2.subgraph(com)):.2f} | avg. cluster coef.: {np.array(list(nx.cluster.clustering(fi_G2.subgraph(com)).values())).mean():.3f}')
# Out:
# community 0: 3119 | density: 0.01 | avg. cluster coef.: 0.335
# community 1: 2539 | density: 0.01 | avg. cluster coef.: 0.369
# community 2: 1365 | density: 0.02 | avg. cluster coef.: 0.490
# community 3: 1349 | density: 0.02 | avg. cluster coef.: 0.477
# community 4: 1336 | density: 0.02 | avg. cluster coef.: 0.461
# community 5: 752 | density: 0.09 | avg. cluster coef.: 0.636
# community 6: 538 | density: 0.09 | avg. cluster coef.: 0.606
# community 7: 426 | density: 0.05 | avg. cluster coef.: 0.498
# community 8: 403 | density: 0.16 | avg. cluster coef.: 0.684
# community 9: 371 | density: 0.05 | avg. cluster coef.: 0.530
# community 10: 303 | density: 0.06 | avg. cluster coef.: 0.625
# community 11: 235 | density: 0.03 | avg. cluster coef.: 0.476
# community 12: 136 | density: 0.12 | avg. cluster coef.: 0.277
# community 13: 135 | density: 0.06 | avg. cluster coef.: 0.386
# community 14: 110 | density: 0.42 | avg. cluster coef.: 0.848
# community 15: 95 | density: 0.10 | avg. cluster coef.: 0.474
# community 16: 94 | density: 0.19 | avg. cluster coef.: 0.106
# community 17: 94 | density: 0.95 | avg. cluster coef.: 0.984
# community 18: 83 | density: 0.04 | avg. cluster coef.: 0.194
# community 19: 47 | density: 0.14 | avg. cluster coef.: 0.371
# community 20: 42 | density: 0.38 | avg. cluster coef.: 0.175
# community 21: 23 | density: 0.15 | avg. cluster coef.: 0.113
# community 22: 19 | density: 0.42 | avg. cluster coef.: 0.818
# community 23: 16 | density: 0.51 | avg. cluster coef.: 0.635
# community 24: 14 | density: 0.22 | avg. cluster coef.: 0.240
# community 25: 13 | density: 0.29 | avg. cluster coef.: 0.872
# community 26: 13 | density: 0.18 | avg. cluster coef.: 0.000
# community 27: 13 | density: 0.36 | avg. cluster coef.: 0.624
# community 28: 10 | density: 0.38 | avg. cluster coef.: 0.000
# community 29: 9 | density: 1.00 | avg. cluster coef.: 1.000
# community 30: 9 | density: 0.42 | avg. cluster coef.: 0.507
# community 31: 8 | density: 0.93 | avg. cluster coef.: 0.919
# community 32: 8 | density: 0.25 | avg. cluster coef.: 0.000
# community 33: 8 | density: 1.00 | avg. cluster coef.: 1.000
# community 34: 7 | density: 0.29 | avg. cluster coef.: 0.000
# community 35: 6 | density: 0.67 | avg. cluster coef.: 0.444
# community 36: 6 | density: 0.73 | avg. cluster coef.: 0.600
# community 37: 6 | density: 0.53 | avg. cluster coef.: 0.633
# community 38: 5 | density: 0.50 | avg. cluster coef.: 0.000
# community 39: 4 | density: 0.67 | avg. cluster coef.: 0.583
# community 40: 4 | density: 1.00 | avg. cluster coef.: 1.000
# community 41: 4 | density: 0.50 | avg. cluster coef.: 0.000
# community 42: 4 | density: 0.50 | avg. cluster coef.: 0.000
# community 43: 4 | density: 0.83 | avg. cluster coef.: 0.833

# %%
_ = [print(x) for x in coms.communities[22] if len(x.split(' ')) == 1]
# Out:
# AIMP1
# AIMP2
# DARS1
# EEF1E1
# EPRS1
# GBP1
# IARS1
# KARS1
# LARS1
# MARS1
# QARS1
# RARS1
# DUS2
# GARS1
# GBP2
# GBP3
# GBP4
# GBP5
# IARS2

# %%
comps = list(nx.connected_components(fi_G3))
sorted([len(x) for x in comps])[::-1][0:5]

fi_G4 = nx.subgraph(fi_G3, comps[0])
len(fi_G4)

# %%
pos = nx.spring_layout(fi_G4, iterations=100, k=1.5, seed=0)

# %%
plt.figure(figsize=(10,10))
nx.draw_networkx_edges(fi_G4, pos=pos, alpha=0.01)
plt.show()

# %%
# what gene has the highest centrality? 
cent = nx.degree_centrality(fi_G4)
max_centrality = sorted(cent.values())[-1]
[k for k,v in cent.items() if v == max_centrality]
